# %% [markdown]
# # PGA TOUR Summary
#
# This notebook shows summary statistics from PGA TOUR Shotlink data for a chosen year.

# %% [markdown]
# # Section 1: Import packages, and load the selected year

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os import getcwd
import os
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')
import plotly.io as pio; pio.renderers.default='notebook'
import pga_tour_sum_funs# DB: Custom functions to reduce size of notebook 
from IPython.display import Markdown as md
from sklearn.linear_model import LinearRegression

# Parameter choices
year = 2021# DB: 2015 - 2021
#min_drives = 25
min_events = 5

df, df_event = pga_tour_sum_funs.load_data(year)
df_measured, df_measured_player = pga_tour_sum_funs.get_measured_data(df, 0)
df_hole_average, df_hole_sum = pga_tour_sum_funs.get_hole_average_data(df, 0)
df_event_player = pga_tour_sum_funs.player_level_data(df, df_event, min_events)
#df_event_player = pga_tour_sum_funs.add_putting(df_event_player, df)
print('Data Loaded for ' + str(year))
# Out:
# Data Loaded for 2021

# %% [markdown]
# # Section 2: Driving Distance

# %% [markdown]
# ## The figure below shows the distribution of measured drives on the PGA TOUR.

# %% [markdown]
# There are generally two measured drives per rounds, on holes chosen to face in roughly opposite directions to negate the impact of wind, and with flat landing ares to avoid bounce and roll having too large an influence on the distance.

# %%
fig = px.histogram(df_measured, x="DrivingDistance_rounded_",
                   title='Driving Distance - Measured Drives (yards) - ' + str(year), histnorm='probability density', nbins = 80)

fig.update_layout(bargap=0.2)
fig.show()
# Out:
# <div>                            <div id="cffd0de7-b426-4b39-b652-a066a08b54a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cffd0de7-b426-4b39-b652-a066a08b54a6")) {                    Plotly.newPlot(                        "cffd0de7-b426-4b39-b652-a066a08b54a6",                        [{"alignmentgroup": "True", "bingroup": "x", "histnorm": "probability density", "hovertemplate": "DrivingDistance_rounded_=%{x}<br>probability density=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 80, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [329, 289, 297, 273, 287, 253, 243, 325, 307, 323, 309, 309, 321, 283, 297, 295, 283, 309, 307, 311, 287, 293, 179, 293, 313, 311, 283, 305, 289, 301, 287, 291, 285, 305, 289, 313, 319, 299, 329, 303, 291, 299, 299, 291, 263, 313, 279, 291, 293, 287, 307, 301, 277, 281, 283, 287, 289, 311, 309, 301, 311, 295, 269, 263, 315, 279, 281, 295, 299, 297, 303, 297, 289, 315, 323, 283, 305, 229, 283, 327, 311, 275, 287, 285, 291, 289, 279, 297, 317, 279, 297, 301, 281, 321, 299, 305, 317, 319, 311, 311, 295, 309, 315, 299, 333, 293, 339, 311, 297, 301, 279, 303, 289, 287, 297, 313, 285, 283, 311, 295, 335, 313, 301, 313, 291, 245, 277, 279, 269, 275, 301, 279, 307, 303, 297, 307, 285, 287, 277, 289, 285, 307, 291, 315, 277, 279, 295, 303, 303, 313, 307, 301, 283, 309, 219, 279, 385, 317, 301, 313, 293, 235, 295, 309, 299, 293, 289, 303, 289, 279, 289, 309, 321, 293, 283, 287, 285, 285, 295, 279, 315, 315, 301, 293, 287, 291, 289, 291, 313, 297, 285, 309, 285, 285, 289, 305, 293, 303, 313, 295, 303, 291, 295, 299, 249, 337, 309, 293, 301, 277, 287, 299, 279, 313, 291, 263, 305, 307, 325, 291, 301, 305, 279, 307, 307, 295, 303, 297, 307, 303, 299, 313, 289, 309, 317, 317, 297, 291, 283, 293, 283, 317, 313, 283, 307, 301, 307, 293, 311, 307, 283, 295, 303, 281, 287, 345, 295, 307, 327, 299, 313, 293, 311, 313, 285, 335, 299, 303, 319, 309, 301, 291, 293, 287, 309, 305, 333, 315, 287, 285, 289, 293, 299, 309, 299, 313, 329, 293, 295, 287, 263, 307, 287, 297, 293, 307, 303, 315, 315, 289, 307, 313, 325, 309, 289, 291, 291, 305, 321, 321, 317, 333, 309, 325, 307, 303, 287, 295, 289, 295, 285, 305, 291, 307, 283, 301, 311, 319, 279, 275, 315, 317, 299, 307, 299, 281, 297, 291, 307, 295, 307, 307, 305, 239, 333, 329, 295, 291, 273, 309, 289, 269, 249, 317, 279, 311, 305, 269, 273, 273, 287, 295, 275, 289, 307, 323, 289, 217, 195, 315, 295, 323, 313, 285, 287, 295, 307, 303, 307, 307, 305, 289, 331, 323, 327, 305, 337, 305, 337, 353, 309, 279, 323, 297, 293, 303, 311, 293, 287, 289, 299, 311, 317, 345, 329, 307, 331, 301, 297, 253, 305, 295, 283, 329, 303, 295, 303, 287, 291, 299, 327, 311, 303, 281, 261, 309, 301, 287, 293, 295, 307, 305, 323, 313, 287, 321, 331, 331, 325, 323, 325, 341, 327, 309, 331, 303, 233, 251, 281, 267, 277, 299, 291, 309, 327, 267, 363, 265, 305, 293, 299, 405, 295, 295, 265, 275, 301, 329, 351, 333, 279, 355, 299, 359, 257, 267, 315, 289, 261, 295, 303, 305, 299, 293, 315, 355, 251, 293, 277, 301, 289, 359, 265, 325, 311, 307, 267, 315, 335, 319, 315, 335, 305, 325, 345, 303, 359, 293, 317, 275, 331, 335, 261, 275, 287, 317, 283, 291, 263, 367, 265, 297, 313, 275, 283, 313, 319, 273, 325, 303, 351, 281, 325, 301, 245, 277, 289, 247, 285, 299, 275, 355, 289, 271, 321, 373, 309, 313, 293, 327, 303, 367, 291, 329, 271, 321, 333, 311, 255, 363, 341, 273, 313, 225, 319, 261, 335, 271, 325, 309, 281, 355, 291, 309, 301, 337, 281, 319, 321, 295, 399, 291, 295, 307, 317, 285, 341, 323, 313, 363, 335, 289, 365, 301, 419, 285, 343, 351, 295, 309, 317, 367, 285, 315, 327, 351, 335, 337, 317, 261, 321, 357, 279, 353, 273, 317, 279, 281, 325, 301, 327, 337, 295, 297, 291, 275, 287 ...

# %% [markdown]
# ## We can also look at the distribution of measured drives on an event by event basis, shown below.

# %% [markdown]
# We can see that there is considerable variabillity both between different events, and also within each event itself.

# %%
fig = px.box(df_measured, x="EventName", y='DrivingDistance_rounded_', \
             color="EventName", labels = '',\
             title='Distribution of Driving Distances by Event - ' + str(year))
fig.update_layout(
    xaxis_visible = False)
fig.show()
# Out:
# <div>                            <div id="491a6785-d03e-4ba8-a9cb-e8ac4d4c4d7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("491a6785-d03e-4ba8-a9cb-e8ac4d4c4d7f")) {                    Plotly.newPlot(                        "491a6785-d03e-4ba8-a9cb-e8ac4d4c4d7f",                        [{"alignmentgroup": "True", "hovertemplate": "EventName=%{x}<br>DrivingDistance_rounded_=%{y}<extra></extra>", "legendgroup": "Safeway Open", "marker": {"color": "#636efa"}, "name": "Safeway Open", "notched": false, "offsetgroup": "Safeway Open", "orientation": "v", "showlegend": true, "type": "box", "x": ["Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway Open", "Safeway O ...

# %% [markdown]
# ## The Top 20 longest players, along with a variety of other stats, are shown below.

# %%
df_temp = df_event_player.sort_values(by='Driving Distance', ascending=False).reset_index()
df_temp.head(20)
# Out:
#     index                Name  Player Number       Money  Driving Distance  \
# 0     152  DeChambeau, Bryson          47959  5409588.11        320.766667
# 1      23      Clark, Wyndham          51766   986801.08        319.380952
# 2     183       McIlroy, Rory          28237  1782341.87        319.125000
# 3     149      Champ, Cameron          52372   645429.34        317.618421
# 4      44     Gordon, William          56762   307583.50        314.658333
# 5     216      Wolff, Matthew          56278  2248853.83        314.640625
# 6     169     Johnson, Dustin          30925  3686600.72        313.250000
# 7      73          List, Luke          27129   538202.50        312.990196
# 8     187    Niemann, Joaquin          45486  2590638.30        312.718750
# 9      25          Daffue, MJ          39067   144276.00        312.464286
# 10     49       Hagy, Brandon          46550   996263.00        312.175000
# 11     27      Davis, Cameron          45157  1040330.25        311.630000
# 12     12         Brehm, Ryan          28420   166210.00        310.671875
# 13    227    Frittelli, Dylan          29970  1014201.55        310.592105
# 14     86     Murray, Grayson          34213   236666.75        308.970588
# 15     34      Garcia, Sergio          21209  2222399.77        308.569444
# 16     79     McCumber, Tyler          40042   916241.89        308.380435
# 17    236      Koepka, Brooks          36689  2823715.33        308.166667
# 18    218     Zalatoris, Will          47483  1942002.33        307.900000
# 19    201         Scott, Adam          24502   662679.72        307.725000
#
#     Driving Accuracy        GIR  Putts Per Round
# 0          58.018868  67.407407        28.500000
# 1          46.075085  66.402116        28.547619
# 2          57.200000  66.049383        28.722222
# 3          56.766917  68.128655        30.315789
# 4          54.186603  67.314815        29.383333
# 5          50.225225  65.798611        28.937500
# 6          58.928571  70.238095        29.285714
# 7          53.792135  66.993464        29.372549
# 8          60.863095  71.527778        28.791667
# 9          53.571429  69.841270        29.500000
# 10         51.071429  64.861111        29.325000
# 11         53.448276  66.666667        28.920000
# 12         55.580357  67.361111        29.375000
# 13         50.000000  65.935673        29.473684
# 14         51.687764  64.052288        29.676471
# 15         59.288538  70.524691        29.472222
# 16         57.608696  64.975845        29.369565
# 17         54.326923  67.962963        28.333333
# 18         54.857143  70.000000        29.420000
# 19         53.392857  66.388889        29.100000

# %% [markdown]
# # Section 3: Driving and Accuracy

# %% [markdown]
# ## The figure below looks at the releationship between driving distance, accuracy and success.

# %% [markdown]
# The size of the bubbles represent the amount of money earned by that player over the course of the season.

# %%
# Bubble plot
fig = px.scatter(df_event_player, x="Driving Distance", y="Driving Accuracy", trendline = 'ols',
         color="Name", size="Money", 
                 hover_name="Name", title='Driving Distance, Accuracy and Money Earned - ' + str(year))

# Do regression
x = df_event_player["Driving Distance"].to_numpy().reshape(-1, 1)
y = df_event_player["Driving Accuracy"].to_numpy().reshape(-1, 1)
model = LinearRegression().fit(x,y)
rsq = model.score(x, y)

# Construct line to plot
lx = [np.min(x), np.max(x)]
ly = lx * model.coef_[0] + model.intercept_[0]

# Add line and text
fig.add_scatter(x=lx, y=ly, mode='lines')
fig.add_annotation(x=280, y=45,
            text='Accuracy = ' + str(np.round(model.coef_[0], 3)) +\
                   ' * Driving Distance + ' + str(np.round(model.intercept_[0],)), \
                  showarrow = False)
fig.add_annotation(x=280, y=42,
            text='r-sq = ' + str(np.round(rsq, 3)), showarrow = False)
fig.show()
# Out:
# <div>                            <div id="853797eb-b1fc-4e08-86c6-ede09772f02c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("853797eb-b1fc-4e08-86c6-ede09772f02c")) {                    Plotly.newPlot(                        "853797eb-b1fc-4e08-86c6-ede09772f02c",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Anderson, Mark<br>Driving Distance=%{x}<br>Driving Accuracy=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Anderson, Mark"], "legendgroup": "Anderson, Mark", "marker": {"color": "#636efa", "size": [82411.25], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Anderson, Mark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [283.86764705882354], "xaxis": "x", "y": [59.87394957983193], "yaxis": "y"}, {"hovertemplate": "Name=Anderson, Mark<extra></extra>", "legendgroup": "Anderson, Mark", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Anderson, Mark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Aphibarnrat, Kiradech<br>Driving Distance=%{x}<br>Driving Accuracy=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Aphibarnrat, Kiradech"], "legendgroup": "Aphibarnrat, Kiradech", "marker": {"color": "#EF553B", "size": [115820.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Aphibarnrat, Kiradech", "orientation": "v", "showlegend": true, "type": "scatter", "x": [288.62], "xaxis": "x", "y": [57.714285714285715], "yaxis": "y"}, {"hovertemplate": "Name=Aphibarnrat, Kiradech<extra></extra>", "legendgroup": "Aphibarnrat, Kiradech", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Aphibarnrat, Kiradech", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Armour, Ryan<br>Driving Distance=%{x}<br>Driving Accuracy=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Armour, Ryan"], "legendgroup": "Armour, Ryan", "marker": {"color": "#00cc96", "size": [344455.96], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Armour, Ryan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [279.45652173913044], "xaxis": "x", "y": [69.62616822429906], "yaxis": "y"}, {"hovertemplate": "Name=Armour, Ryan<extra></extra>", "legendgroup": "Armour, Ryan", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Armour, Ryan", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Baddeley, Aaron<br>Driving Distance=%{x}<br>Driving Accuracy=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Baddeley, Aaron"], "legendgroup": "Baddeley, Aaron", "marker": {"color": "#ab63fa", "size": [65940.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Baddeley, Aaron", "orientation": "v", "showlegend": true, "type": "scatter", "x": [283.34375], "xaxis": "x", "y": [56.91964285714286], "yaxis": "y"}, {"hovertemplate": "Name=Baddeley, Aaron<extra></extra>", "legendgroup": "Baddeley, Aaron", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Baddeley, Aaron", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Bae, Sangmoon<br>Driving Distance=%{x}<br>Driving Accuracy=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Bae, Sangmoon"], "legendgroup": "Bae, Sangmoon", "marker": {"color": "#FFA15A", "size": [33700.0], "sizemode": "area", "sizeref": 13549. ...

# %% [markdown]
# # Section 4: Accuracy

# %% [markdown]
# ## The distribution of driving accuracy and GIR percentage by player is shown below.

# %%
fig = px.histogram(df_event_player, x="Driving Accuracy",
                   title='Driving Accuracy Percentage by Player - ' + str(year),  nbins = 50)

101010101, 67.1146953405018, 65.35087719298247, 70.22222222222221, 65.90038314176245, 66.66666666666666, 67.46031746031747, 63.70370370370371, 64.1025641025641, 65.41666666666667, 55.87301587301587, 69.23868312757202, 69.44444444444444, 58.611111111111114, 63.213213213213216, 67.512077294686, 66.18357487922705, 64.23611111111111, 65.17615176151762, 61.111111111111114, 63.69047619047619, 64.61352657004831, 65.12345679012346, 71.82539682539682, 63.77314814814815, 64.8989898989899, 71.06481481481481, 61.111111111111114, 70.46783625730994, 58.88888888888889, 69.88304093567251, 68.13725490196079, 68.12865497076024, 71.39917695473251, 67.31266149870801, 67.4074074074074, 66.93121693121694, 68.81313131313132, 66.14583333333334, 64.68253968253968, 64.33333333333333, 66.76954732510289, 62.60683760683761, 65.94650205761316, 67.03703703703704, 66.99346405228758, 65.04629629629629, 69.57070707070707, 70.76719576719577, 67.6328502415459, 64.77272727272727, 69.6969696969697, 70.23809 ...

# %% [markdown]
# ## In a similar way as we did above with driving accuracy and driving distance, we can look at the relationship between driving accuracy, GIR and money earned.

# %%
fig = px.scatter(df_event_player, x="Driving Accuracy", y="GIR", 
         color="Name", size="Money", 
                 hover_name="Name", title='Driving Accuracy, GIR and Money Earned - ' + str(year))
# Do regression
x = df_event_player["Driving Accuracy"].to_numpy().reshape(-1, 1)
y = df_event_player["GIR"].to_numpy().reshape(-1, 1)
model = LinearRegression().fit(x,y)
rsq = model.score(x, y)

# Construct line to plot
lx = [np.min(x), np.max(x)]
ly = lx * model.coef_[0] + model.intercept_[0]

# Add line and text
fig.add_scatter(x=lx, y=ly, mode='lines')
fig.add_annotation(x=55, y=55,
            text='GIR = ' + str(np.round(model.coef_[0], 3)) +\
                   ' * Driving Accuracy + ' + str(np.round(model.intercept_[0],)), \
                  showarrow = False)
fig.add_annotation(x=55, y=52,
            text='r-sq = ' + str(np.round(rsq, 3)), showarrow = False)
fig.show()
# Out:
# <div>                            <div id="a5f42f6f-17a4-4924-8cb7-5c791a721a29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5f42f6f-17a4-4924-8cb7-5c791a721a29")) {                    Plotly.newPlot(                        "a5f42f6f-17a4-4924-8cb7-5c791a721a29",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Anderson, Mark<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Anderson, Mark"], "legendgroup": "Anderson, Mark", "marker": {"color": "#636efa", "size": [82411.25], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Anderson, Mark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [59.87394957983193], "xaxis": "x", "y": [68.79084967320262], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Aphibarnrat, Kiradech<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Aphibarnrat, Kiradech"], "legendgroup": "Aphibarnrat, Kiradech", "marker": {"color": "#EF553B", "size": [115820.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Aphibarnrat, Kiradech", "orientation": "v", "showlegend": true, "type": "scatter", "x": [57.714285714285715], "xaxis": "x", "y": [57.99999999999999], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Armour, Ryan<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Armour, Ryan"], "legendgroup": "Armour, Ryan", "marker": {"color": "#00cc96", "size": [344455.96], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Armour, Ryan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [69.62616822429906], "xaxis": "x", "y": [64.61352657004831], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Baddeley, Aaron<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Baddeley, Aaron"], "legendgroup": "Baddeley, Aaron", "marker": {"color": "#ab63fa", "size": [65940.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Baddeley, Aaron", "orientation": "v", "showlegend": true, "type": "scatter", "x": [56.91964285714286], "xaxis": "x", "y": [64.93055555555556], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Bae, Sangmoon<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Bae, Sangmoon"], "legendgroup": "Bae, Sangmoon", "marker": {"color": "#FFA15A", "size": [33700.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Bae, Sangmoon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [56.25], "xaxis": "x", "y": [59.375], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Baker, Chris<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Baker, Chris"], "legendgroup": "Baker, Chris", "marker": {"color": "#19d3f3", "size": [65448.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Baker, Chris", "orientation": "v", "showlegend": true, "type": "scatter", "x": [67.3469387755102], "xaxis": "x", "y": [65.07936507936508], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Barnes, Ricky<br>Driving Accuracy=%{x}<br>GIR=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Barnes, Ricky"], "legendgroup": "Barnes, Ricky", "marker": {"color": "#FF6692", "size": [79001.82], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Barnes, Ricky",  ...

# %% [markdown]
# ## The Top 20 players in driving accuracy percentage, along with a variety of other stats, are shown below.

# %%
df_temp = df_event_player.sort_values(by='Driving Accuracy', ascending=False).reset_index()
df_temp.head(20)
# Out:
#     index              Name  Player Number       Money  Driving Distance  \
# 0     208     Todd, Brendon          30927   960939.16        275.800000
# 1     238       Moore, Ryan          26596   147266.00        287.975000
# 2     143    Ancer, Abraham          45526  1694962.28        289.968750
# 3     121     Stuard, Brian          31560   586186.66        281.241379
# 4     173     Kisner, Kevin          29478  1196576.44        287.029412
# 5     202     Simpson, Webb          29221  1628989.85        292.881579
# 6      61     Kim, Joohyung          55182    98258.00        294.305556
# 7      35    Garnett, Brice          29535   426153.17        288.351852
# 8     168       Im, Sungjae          39971  2604052.60        297.431818
# 9     150    Conners, Corey          39997  2440045.00        294.537037
# 10    100      Reavie, Chez          26476   585732.28        280.613636
# 11    184  Morikawa, Collin          50525  2588517.33        293.888889
# 12      2      Armour, Ryan          19803   344455.96        279.456522
# 13    125      Teater, Josh          27330   103138.60        287.961538
# 14     52      Hearn, David          26758   307788.00        275.815789
# 15     33        Furyk, Jim          10809   184897.33        284.275000
# 16    228  Kodaira, Satoshi          32816   164045.00        286.079545
# 17     68     Laird, Martin          27936  1534884.33        296.022727
# 18    234    Landry, Andrew          33410   502458.00        292.119048
# 19    102        Roach, Wes          35732    91558.00        290.444444
#
#     Driving Accuracy        GIR  Putts Per Round
# 0          72.714286  64.888889        28.280000
# 1          72.142857  65.555556        29.400000
# 2          72.023810  71.064815        28.916667
# 3          71.905941  65.900383        28.931034
# 4          71.848739  66.830065        28.470588
# 5          71.428571  70.614035        28.710526
# 6          70.238095  66.358025        28.555556
# 7          70.212766  67.489712        28.907407
# 8          69.891304  69.696970        28.696970
# 9          69.652406  71.399177        29.240741
# 10         69.642857  68.308081        29.772727
# 11         69.642857  72.530864        28.861111
# 12         69.626168  64.613527        28.608696
# 13         69.505495  64.102564        28.461538
# 14         68.679245  64.766082        28.578947
# 15         68.571429  68.888889        29.500000
# 16         68.421053  64.015152        29.159091
# 17         68.122977  71.085859        29.977273
# 18         68.088737  64.153439        29.238095
# 19         67.857143  65.123457        29.222222

# %% [markdown]
# ## And the table below shows a similar table for the Top 20 players in GIR percentage.

# %%
df_temp = df_event_player.sort_values(by='GIR', ascending=False).reset_index()
df_temp.head(20)
# Out:
#     index              Name  Player Number       Money  Driving Distance  \
# 0      22     Cink, Stewart          20229  1720715.00        305.452381
# 1      87  NeSmith, Matthew          36871   943614.49        297.634615
# 2      46  Grillo, Emiliano          31646   850127.59        299.350000
# 3      93    Percy, Cameron          22056   505731.00        283.833333
# 4     184  Morikawa, Collin          50525  2588517.33        293.888889
# 5     195         Rahm, Jon          46970  2969382.33        306.062500
# 6     140       Wise, Aaron          49964  1254218.26        302.238095
# 7     232   Henley, Russell          34098  1650170.36        290.226190
# 8      50       Hahn, James          32448  1048184.50        299.845238
# 9     187  Niemann, Joaquin          45486  2590638.30        312.718750
# 10    150    Conners, Corey          39997  2440045.00        294.537037
# 11     65     Knox, Russell          33122   805597.35        291.076923
# 12     68     Laird, Martin          27936  1534884.33        296.022727
# 13    143    Ancer, Abraham          45526  1694962.28        289.968750
# 14    165   Hovland, Viktor          46717  3534091.60        301.607143
# 15    191      Palmer, Ryan          23320  1969261.08        302.869048
# 16    202     Simpson, Webb          29221  1628989.85        292.881579
# 17    174     Kokrak, Jason          30944  3075908.21        304.065217
# 18     34    Garcia, Sergio          21209  2222399.77        308.569444
# 19    145    Berger, Daniel          40026  2668829.64        297.855263
#
#     Driving Accuracy        GIR  Putts Per Round
# 0          58.983051  74.074074        29.476190
# 1          65.426997  73.290598        30.057692
# 2          64.200477  73.055556        29.383333
# 3          63.265306  72.751323        29.642857
# 4          69.642857  72.530864        28.861111
# 5          61.964286  72.500000        29.400000
# 6          54.280822  71.825397        30.023810
# 7          67.241379  71.693122        28.952381
# 8          65.753425  71.560847        29.119048
# 9          60.863095  71.527778        28.791667
# 10         69.652406  71.399177        29.240741
# 11         64.640884  71.367521        29.769231
# 12         68.122977  71.085859        29.977273
# 13         72.023810  71.064815        28.916667
# 14         62.157534  70.767196        28.928571
# 15         59.183673  70.634921        28.666667
# 16         71.428571  70.614035        28.710526
# 17         62.111801  70.531401        28.978261
# 18         59.288538  70.524691        29.472222
# 19         63.909774  70.467836        28.578947

# %% [markdown]
# # Section 5: Putting

# %%
fig = px.histogram(df_event_player, x="Putts Per Round",
                   title='Putts per Round - ' + str(year), nbins = 80)

fig.update_layout(bargap=0.2)
mean_ppr = np.mean(df_event_player["Putts Per Round"])

fig.add_annotation(x=28, y=10,
            text='Average PPR = ' + str(np.round(mean_ppr, 2)), showarrow = False)
fig.show()
df_event_player
# Out:
# <div>                            <div id="e114afba-1f97-4ba8-93f1-40af9593711d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e114afba-1f97-4ba8-93f1-40af9593711d")) {                    Plotly.newPlot(                        "e114afba-1f97-4ba8-93f1-40af9593711d",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Putts Per Round=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "nbinsx": 80, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x":
# 4            Bae, Sangmoon          28259    33700.00        290.656250
# ..                     ...            ...         ...               ...
# 235    Molinari, Francesco          25198   751581.00        292.178571
# 236         Koepka, Brooks          36689  2823715.33        308.166667
# 237    Harrington, Padraig          20766   151888.34        300.383333
# 238            Moore, Ryan          26596   147266.00        287.975000
# 239         Noh, Seung-Yul          29289    17941.00        300.041667
#
#      Driving Accuracy        GIR  Putts Per Round
# 0           59.873950  68.790850        29.676471
# 1           57.714286  58.000000        28.280000
# 2           69.626168  64.613527        28.608696
# 3           56.919643  64.930556        28.500000
# 4           56.250000  59.375000        28.562500
# ..                ...        ...              ...
# 235         60.567010  63.690476        28.500000
# 236         54.326923  67.962963        28.333333
# 237         55.048077  60.185185        28.900000
# 238         72.142857  65.555556        29.400000
# 239         48.809524  62.500000        29.000000
#
# [240 rows x 7 columns]

# %% [markdown]
# ## The relationship between PPR, GIR and money earned is shown below.

# %%
# Bubble plot
fig = px.scatter(df_event_player, x="GIR", y="Putts Per Round",
         color="Name", size="Money", 
                 hover_name="Name", title='GIR, Putts Per Round and Money Earned - ' + str(year))

# Do regression
x = df_event_player["GIR"].to_numpy().reshape(-1, 1)
y = df_event_player["Putts Per Round"].to_numpy().reshape(-1, 1)
model = LinearRegression().fit(x,y)
rsq = model.score(x, y)

# Construct line to plot
lx = [np.min(x), np.max(x)]
ly = lx * model.coef_[0] + model.intercept_[0]

# Add line and text
fig.add_scatter(x=lx, y=ly, mode='lines')
fig.add_annotation(x=50, y=30.5,
            text='PPR = ' + str(np.round(model.coef_[0], 3)) +\
                   ' * GIR + ' + str(np.round(model.intercept_[0],)), \
                  showarrow = False)
fig.add_annotation(x=50, y=30,
            text='r-sq = ' + str(np.round(rsq, 3)), showarrow = False)
fig.show()
# Out:
# <div>                            <div id="554ca175-867e-4695-9ed0-9448177de1ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("554ca175-867e-4695-9ed0-9448177de1ef")) {                    Plotly.newPlot(                        "554ca175-867e-4695-9ed0-9448177de1ef",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Anderson, Mark<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Anderson, Mark"], "legendgroup": "Anderson, Mark", "marker": {"color": "#636efa", "size": [82411.25], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Anderson, Mark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [68.79084967320262], "xaxis": "x", "y": [29.676470588235293], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Aphibarnrat, Kiradech<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Aphibarnrat, Kiradech"], "legendgroup": "Aphibarnrat, Kiradech", "marker": {"color": "#EF553B", "size": [115820.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Aphibarnrat, Kiradech", "orientation": "v", "showlegend": true, "type": "scatter", "x": [57.99999999999999], "xaxis": "x", "y": [28.28], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Armour, Ryan<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Armour, Ryan"], "legendgroup": "Armour, Ryan", "marker": {"color": "#00cc96", "size": [344455.96], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Armour, Ryan", "orientation": "v", "showlegend": true, "type": "scatter", "x": [64.61352657004831], "xaxis": "x", "y": [28.608695652173914], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Baddeley, Aaron<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Baddeley, Aaron"], "legendgroup": "Baddeley, Aaron", "marker": {"color": "#ab63fa", "size": [65940.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Baddeley, Aaron", "orientation": "v", "showlegend": true, "type": "scatter", "x": [64.93055555555556], "xaxis": "x", "y": [28.5], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Bae, Sangmoon<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Bae, Sangmoon"], "legendgroup": "Bae, Sangmoon", "marker": {"color": "#FFA15A", "size": [33700.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Bae, Sangmoon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [59.375], "xaxis": "x", "y": [28.5625], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Baker, Chris<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Baker, Chris"], "legendgroup": "Baker, Chris", "marker": {"color": "#19d3f3", "size": [65448.0], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Baker, Chris", "orientation": "v", "showlegend": true, "type": "scatter", "x": [65.07936507936508], "xaxis": "x", "y": [29.607142857142858], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Name=Barnes, Ricky<br>GIR=%{x}<br>Putts Per Round=%{y}<br>Money=%{marker.size}<extra></extra>", "hovertext": ["Barnes, Ricky"], "legendgroup": "Barnes, Ricky", "marker": {"color": "#FF6692", "size": [79001.82], "sizemode": "area", "sizeref": 13549.401899999999, "symbol": "circle"}, "mode": "markers", "name": "Barnes, Ricky", "orientation": "v", "showle ...

# %% [markdown]
# ## The table below shows a similar table for the Top 20 players in PPR.

# %%
df_temp = df_event_player.sort_values(by='Putts Per Round', ascending=True).reset_index()
df_temp.head(20)
# Out:
#     index                      Name  Player Number       Money  \
# 0     130            Uihlein, Peter          29484    75356.00
# 1     196             Reed, Patrick          34360  2514654.62
# 2      67           Lahiri, Anirban          31420   632237.25
# 3     113            Spieth, Jordan          34046  3024056.04
# 4     117            Stefani, Shawn          33418        0.00
# 5      77            Malnati, Peter          34466  1333148.82
# 6     203            Smith, Cameron          35891  2799044.67
# 7      57                 Hoge, Tom          35532  1145746.64
# 8     206            Thomas, Justin          33448  5419760.76
# 9     163                 Homa, Max          39977  2664442.44
# 10     14             Bryan, Wesley          48084   193765.66
# 11      9         Bozzelli, Dominic          40009     9160.00
# 12     91             Ortiz, Carlos          33667  2249905.11
# 13    153           English, Harris          34099  3371448.24
# 14    208             Todd, Brendon          30927   960939.16
# 15      1     Aphibarnrat, Kiradech          30978   115820.00
# 16    146  Bezuidenhout, Christiaan          45522   555186.00
# 17    160             Harman, Brian          27644  1951603.49
# 18    198              Rose, Justin          22405   269326.35
# 19    236            Koepka, Brooks          36689  2823715.33
#
#     Driving Distance  Driving Accuracy        GIR  Putts Per Round
# 0         286.550000         44.285714  58.611111        27.750000
# 1         287.406250         64.508929  65.625000        27.812500
# 2         296.828947         49.436090  63.742690        27.815789
# 3         297.522727         50.163934  63.636364        27.909091
# 4         274.090909         53.246753  51.010101        27.909091
# 5         290.695652         57.763975  64.371981        27.913043
# 6         296.821429         56.632653  66.534392        27.976190
# 7         289.169643         61.053985  64.781746        28.053571
# 8         300.434211         58.834586  69.736842        28.078947
# 9         303.260417         56.586826  65.046296        28.083333
# 10        297.272727         48.051948  60.858586        28.136364
# 11        286.785714         50.000000  51.984127        28.142857
# 12        303.218750         60.029940  68.865741        28.187500
# 13        296.357143         65.306122  66.931217        28.238095
# 14        275.800000         72.714286  64.888889        28.280000
# 15        288.620000         57.714286  58.000000        28.280000
# 16        285.950000         61.071429  58.888889        28.300000
# 17        292.398148         65.106952  65.946502        28.314815
# 18        299.386364         59.210526  64.646465        28.318182
# 19        308.166667         54.326923  67.962963        28.333333
